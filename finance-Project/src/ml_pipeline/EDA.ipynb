# %%
import pandas as pd
import sweetviz as sv

import json
ml_pipeline_config = open('../../config/ml_pipeline.json')
ml_pipeline_config = json.load(ml_pipeline_config)

# %%
df = pd.read_csv(ml_pipeline_config["processed_data_path"])
report = sv.analyze(df)
report.show_html("report.html")
# Out:
# Done! Use 'show' commands to display/save.   |█████████████████████████████████████████| [100%]   00:00 -> (00:00 left)
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
report = sv.analyze(df)
report.show_notebook()
# Out:
# Done! Use 'show' commands to display/save.   |█████████████████████████████████████████| [100%]   00:00 -> (00:00 left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
report = sv.analyze(df)
# Out:
# Done! Use 'show' commands to display/save.   |█████████████████████████████████████████| [100%]   00:00 -> (00:00 left)

# %%
for variable_name in df.columns:
    feature_report = report.feature_config[variable_name]
    fig, ax = sv.graph_feature(feature_report)
    plt.savefig(f"{variable_name}_visualization.png")
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 for variable_name in df.columns:
# ----> 2     feature_report = report.feature_config[variable_name]
#       3     fig, ax = sv.graph_feature(feature_report)
#       4     plt.savefig(f"{variable_name}_visualization.png")
#
# AttributeError: 'DataframeReport' object has no attribute 'feature_config'

# %%
# Save each visualization to individual HTML files
for variable_name, visualization in report.show_html().items():
    visualization.save(f"{variable_name}_visualization.html")
